# %% [markdown]
# # Brenda's Visualization + Reflection

# %% [markdown]
# ### **PART 1: OVERVIEW**

# %% [markdown]
# Our project aims to predict obesity in individuals by analyzing various health and lifestyle factors. Using a primary dataset from the CDC on health indicators, along with a secondary dataset focused on obesity in Latin American individuals, we aim to develop a model that can identify individuals at higher risk of obesity. The data includes variables such as age, BMI, physical activity, smoking status, and dietary habits, which are strong indicators of an individual’s health profile. By analyzing these features, we seek to uncover patterns and influential predictors that contribute to obesity. Ultimately, our model's goal is to aid in obesity risk prediction, potentially guiding preventive healthcare measures.

# %% [markdown]
# ### **PART 2: UPDATED SCOPE CHANGES**

# %% [markdown]
# Since our initial proposal, we have refined our project scope to focus on predicting obesity rather than both obesity and diabetes. This change was advised after discussing with our professor and determining that diabetes prediction would be challenging without labeled data in our secondary dataset. In addition, we have integrated a secondary dataset containing information on obesity in Latin American individuals, which will allow us to validate our model across diverse demographics and potentially enhance its generalizability.

# %% [markdown]
# ### **PART 3: VISUALIZATION**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the Latin American dataset

# %%
latin_america_data = pd.read_csv('latin_america_obesity.csv')

# %% [markdown]
# 1. BMI for Latin America Datasets
# 2. common age bins + labels to compare

# %%
latin_america_data['Calculated_BMI'] = latin_america_data['Weight'] / (latin_america_data['Height'] ** 2)
age_bins = [18, 24, 29, 34, 39, 44, 49, 54, 59, 64, 69, 74, 79, float('inf')]
age_labels = ['18-24', '25-29', '30-34', '35-39', '40-44', '45-49', '50-54', '55-59', '60-64', '65-69', '70-74', '75-79', '80+']

# %%
latin_america_data['Age_Range'] = pd.cut(latin_america_data['Age'], bins=age_bins, labels=age_labels)

# %% [markdown]
# BMI Distribution Plot for Latin America

# %%
plt.figure(figsize=(16, 10))
sns.boxplot(
    data=latin_america_data, 
    x='Age_Range', 
    y='Calculated_BMI', 
    color='#CA9BF7',
    width=0.6, 
    linewidth=2, 
    fliersize=8, 
    flierprops=dict(marker='o', color='coral', alpha=0.6)
)

# Customize titles and labels for a friendly look
plt.title('BMI Distribution Across Age Groups\n(Latin American Dataset)', fontsize=20, fontweight='bold', color='teal')
plt.xlabel('Age Group', fontsize=16, color='dimgray')
plt.ylabel('BMI', fontsize=16, color='dimgray')

# Rotate x-axis labels for readability
plt.xticks(rotation=45, ha='right', fontsize=14)
plt.yticks(fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.4)

# Display without legend for a cleaner look
plt.tight_layout(pad=2)
plt.show()

# %% [markdown]
# ### **PART 4: REFLECTION**

# %% [markdown]
# Our biggest challenges at this stage include:
# * Handling Class Imbalance: With a higher proportion of non-obese individuals in the CDC dataset, there’s a risk that our model may become biased towards predicting the majority class. We plan to experiment with resampling techniques or adjusting class weights in the model to address this.
# * Integrating the Secondary Dataset: The Latin American dataset includes unique features and categorical variables not present in the CDC data
# * Model Selection and Evaluation: Identifying the most suitable model for our data and accurately assessing its performance
